# %% [markdown]
# 绘制 函数 $f(x)=2x+3$ 和它的反函数 $f(x)=\frac{x-3}{2}$ 的图像

# %%
import numpy as np
import matplotlib.pyplot as plt

# 定义函数和反函数
def f(x):
    return 2 * x + 3

def f_inv(x):
    return (x - 3) / 2

# 生成数据
x = np.linspace(-10, 10, 400)
y = f(x)
y_inv = f_inv(x)

# 绘制函数图像
plt.figure(figsize=(8, 6))

# 绘制 f(x)
plt.plot(x, y, label='f(x) = 2x + 3', color='blue')
plt.plot(x, y_inv, label='f_inv(x) = (x - 3) / 2', color='red')

# 绘制 y = x 线
plt.plot(x, x, '--', color='gray', label='y = x')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Function and Its Inverse')
plt.legend()
plt.grid(True)
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.show()
